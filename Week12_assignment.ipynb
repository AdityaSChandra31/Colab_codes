# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaSChandra31/Colab_codes/blob/main/Week12_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph( )
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([ (3,4),(2,3),(4,5),(1, 2),(5,1)])
nx.draw(G, with_labels=True, node_color='lightblue',edge_color='gray', node_size=1000, font_size=16)
plt.show()

# %%
import networkx as nx

G = nx. Graph()
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
print(len(G.nodes()), len(G.edges()))
# Out:
# 4 4

# %%
def collatz_steps(n):
  steps = 0
  while n != 1:
    n = n // 2 if n % 2 == 0 else 3 * n + 1
    steps += 1
  return steps

print(collatz_steps(7))
# Out:
# 16

# %%
def modified_collatz(n):
  sequence = [n]
  while len(sequence) < 10:
    if n % 2 == 0:
     n = n//2
    else:
     n = 5 * n + 1
    sequence. append(n)
  print(sequence)

modified_collatz(7)
# Out:
# [7, 36, 18, 9, 46, 23, 116, 58, 29, 146]
